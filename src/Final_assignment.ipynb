# %% [markdown]
# <a href="https://www.bigdatauniversity.com"><img src="https://ibm.box.com/shared/static/cw2c7r3o20w9zn8gkecaeyjhgw3xdgbj.png" width="400" align="center"></a>
#
# <h1 align="center"><font size="5">Classification with Python</font></h1>

# %% [markdown]
# In this notebook we try to practice all the classification algorithms that we learned in this course.
#
# We load a dataset using Pandas library, and apply the following algorithms, and find the best one for this specific dataset by accuracy evaluation methods.
#
# Lets first load required libraries:

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import pandas as pd
import numpy as np
import matplotlib.ticker as ticker
from sklearn import preprocessing
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### About dataset

# %% [markdown]
# This dataset is about the performance of basketball teams. The __cbb.csv__ data set includes performance data about five seasons of 354 basketball teams. It includes following fields:
#
# | Field          | Description                                                                           |
# |----------------|---------------------------------------------------------------------------------------|
# |TEAM |	The Division I college basketball school|
# |CONF|	The Athletic Conference in which the school participates in (A10 = Atlantic 10, ACC = Atlantic Coast Conference, AE = America East, Amer = American, ASun = ASUN, B10 = Big Ten, B12 = Big 12, BE = Big East, BSky = Big Sky, BSth = Big South, BW = Big West, CAA = Colonial Athletic Association, CUSA = Conference USA, Horz = Horizon League, Ivy = Ivy League, MAAC = Metro Atlantic Athletic Conference, MAC = Mid-American Conference, MEAC = Mid-Eastern Athletic Conference, MVC = Missouri Valley Conference, MWC = Mountain West, NEC = Northeast Conference, OVC = Ohio Valley Conference, P12 = Pac-12, Pat = Patriot League, SB = Sun Belt, SC = Southern Conference, SEC = South Eastern Conference, Slnd = Southland Conference, Sum = Summit League, SWAC = Southwestern Athletic Conference, WAC = Western Athletic Conference, WCC = West Coast Conference)|
# |G|	Number of games played|
# |W|	Number of games won|
# |ADJOE|	Adjusted Offensive Efficiency (An estimate of the offensive efficiency (points scored per 100 possessions) a team would have against the average Division I defense)|
# |ADJDE|	Adjusted Defensive Efficiency (An estimate of the defensive efficiency (points allowed per 100 possessions) a team would have against the average Division I offense)|
# |BARTHAG|	Power Rating (Chance of beating an average Division I team)|
# |EFG_O|	Effective Field Goal Percentage Shot|
# |EFG_D|	Effective Field Goal Percentage Allowed|
# |TOR|	Turnover Percentage Allowed (Turnover Rate)|
# |TORD|	Turnover Percentage Committed (Steal Rate)|
# |ORB|	Offensive Rebound Percentage|
# |DRB|	Defensive Rebound Percentage|
# |FTR|	Free Throw Rate (How often the given team shoots Free Throws)|
# |FTRD|	Free Throw Rate Allowed|
# |2P_O|	Two-Point Shooting Percentage|
# |2P_D|	Two-Point Shooting Percentage Allowed|
# |3P_O|	Three-Point Shooting Percentage|
# |3P_D|	Three-Point Shooting Percentage Allowed|
# |ADJ_T|	Adjusted Tempo (An estimate of the tempo (possessions per 40 minutes) a team would have against the team that wants to play at an average Division I tempo)|
# |WAB|	Wins Above Bubble (The bubble refers to the cut off between making the NCAA March Madness Tournament and not making it)|
# |POSTSEASON|	Round where the given team was eliminated or where their season ended (R68 = First Four, R64 = Round of 64, R32 = Round of 32, S16 = Sweet Sixteen, E8 = Elite Eight, F4 = Final Four, 2ND = Runner-up, Champion = Winner of the NCAA March Madness Tournament for that given year)|
# |SEED|	Seed in the NCAA March Madness Tournament|
# |YEAR|	Season

# %% [markdown]
# ### Load Data From CSV File

# %% [markdown]
# Let's load the dataset [NB Need to provide link to csv file]

# %%
df = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0120ENv3/Dataset/ML0101EN_EDX_skill_up/cbb.csv')
df.head()
# Out:
#              TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0  North Carolina  ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1       Villanova   BE  40  35  123.1   90.9   0.9703   56.1   46.7  16.3
# 2      Notre Dame  ACC  36  24  118.3  103.3   0.8269   54.0   49.5  15.3
# 3        Virginia  ACC  37  29  119.9   91.0   0.9600   54.8   48.4  15.1
# 4          Kansas  B12  37  32  120.9   90.4   0.9662   55.7   45.1  17.8
#
#    ...  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR
# 0  ...  30.4  53.9  44.6  32.7  36.2   71.7   8.6         2ND   1.0  2016
# 1  ...  30.0  57.4  44.1  36.2  33.9   66.7   8.9   Champions   2.0  2016
# 2  ...  26.0  52.9  46.5  37.4  36.9   65.5   2.3          E8   6.0  2016
# 3  ...  33.4  52.6  46.3  40.3  34.7   61.9   8.6          E8   1.0  2016
# 4  ...  37.3  52.7  43.4  41.3  32.5   70.1  11.6          E8   1.0  2016
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (1406, 24)

# %% [markdown]
# ## Add Column
# Next we'll add a column that will contain "true" if the wins above bubble are over 7 and "false" if not. We'll call this column Win Index or "windex" for short.

# %%
df['windex'] = np.where(df.WAB > 7, 'True', 'False')

# %% [markdown]
# # Data visualization and pre-processing

# %% [markdown]
# Next we'll filter the data set to the teams that made the Sweet Sixteen, the Elite Eight, and the Final Four in the post season. We'll also create a new dataframe that will hold the values with the new column.

# %%
df1 = df.loc[df['POSTSEASON'].str.contains('F4|S16|E8', na=False)]
df1.head()
# Out:
#          TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  ...  \
# 2  Notre Dame  ACC  36  24  118.3  103.3   0.8269   54.0   49.5  15.3  ...
# 3    Virginia  ACC  37  29  119.9   91.0   0.9600   54.8   48.4  15.1  ...
# 4      Kansas  B12  37  32  120.9   90.4   0.9662   55.7   45.1  17.8  ...
# 5      Oregon  P12  37  30  118.4   96.2   0.9163   52.3   48.9  16.1  ...
# 6    Syracuse  ACC  37  23  111.9   93.6   0.8857   50.0   47.3  18.1  ...
#
#    2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR  windex
# 2  52.9  46.5  37.4  36.9   65.5   2.3          E8   6.0  2016   False
# 3  52.6  46.3  40.3  34.7   61.9   8.6          E8   1.0  2016    True
# 4  52.7  43.4  41.3  32.5   70.1  11.6          E8   1.0  2016    True
# 5  52.6  46.1  34.4  36.2   69.0   6.7          E8   1.0  2016   False
# 6  47.2  48.1  36.0  30.7   65.5  -0.3          F4  10.0  2016   False
#
# [5 rows x 25 columns]

# %%
df1['POSTSEASON'].value_counts()
# Out:
# S16    32
# E8     16
# F4      8
# Name: POSTSEASON, dtype: int64

# %% [markdown]
# 32 teams made it into the Sweet Sixteen, 16 into the Elite Eight, and 8 made it into the Final Four over 5 seasons.

# %% [markdown]
# Lets plot some columns to underestand data better:

# %%
# notice: installing seaborn might takes a few minutes
# !conda install -c anaconda seaborn -y
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2020.10.14-0           --> 2020.10.14-0      anaconda
#     openssl:         1.1.1h-h7b6447c_0      --> 1.1.1h-h7b6447c_0 anaconda
#     seaborn:         0.9.0-pyh91ea838_1     --> 0.11.0-py_0       anaconda
#
# The following packages will be DOWNGRADED:
#
#     certifi:         2020.6.20-pyhd3eb1b0_3 --> 2020.6.20-py36_0  anaconda
#
# Preparing transaction: done
# Verifying transaction: failed
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'bin/c_rehash'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'bin/openssl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/aes.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/asn1.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/asn1_mac.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/asn1err.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/asn1t.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/async.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/asyncerr.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/bio.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/bioerr.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/blowfish.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/bn.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/bnerr.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/buffer.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/buffererr.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/camellia.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/cast.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/cmac.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/cms.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/cmserr.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/comp.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/comperr.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/conf.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/conf_api.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/conferr.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/crypto.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/cryptoerr.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/ct.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/cterr.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/des.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/dh.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/dherr.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/dsa.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/dsaerr.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/dtls1.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/e_os2.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/ebcdic.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/ec.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/ecdh.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/ecdsa.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/ecerr.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/engine.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/engineerr.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/err.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/evp.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/evperr.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/hmac.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/idea.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/kdf.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/kdferr.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/lhash.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/md2.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/md4.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/md5.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/mdc2.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/modes.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/obj_mac.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/objects.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/objectserr.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/ocsp.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/ocsperr.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/opensslconf.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/opensslv.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/ossl_typ.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/pem.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/pem2.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/pemerr.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/pkcs12.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/pkcs12err.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/pkcs7.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/pkcs7err.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/rand.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/rand_drbg.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/randerr.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/rc2.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/rc4.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/rc5.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/ripemd.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/rsa.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/rsaerr.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/safestack.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/seed.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/sha.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/srp.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/srtp.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/ssl.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/ssl2.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/ssl3.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/sslerr.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/stack.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/store.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/storeerr.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/symhacks.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/tls1.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/ts.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/tserr.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/txt_db.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/ui.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/uierr.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/whrlpool.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/x509.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/x509_vfy.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/x509err.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/x509v3.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'include/openssl/x509v3err.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'lib/libcrypto.a'
# specified in the package manifest cannot be found.
#
# SafetyError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'lib/libcrypto.so.1.1'
# has an incorrect size.
#   reported size: 3279216 bytes
#   actual size: 1835008 bytes
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'lib/libssl.a'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'lib/pkgconfig/libcrypto.pc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'lib/pkgconfig/libssl.pc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'lib/pkgconfig/openssl.pc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'ssl/ct_log_list.cnf'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'ssl/ct_log_list.cnf.dist'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'ssl/misc/tsget'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'ssl/openssl.cnf'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for openssl located at /opt/conda/pkgs/openssl-1.1.1h-h7b6447c_0
# appears to be corrupted. The path 'ssl/openssl.cnf.dist'
# specified in the package manifest cannot be found.

# %%
bins = np.linspace(df1.BARTHAG.min(), df1.BARTHAG.max(), 10)
g = sns.FacetGrid(df1, col="windex", hue="POSTSEASON", palette="Set1", col_wrap=6)
g.map(plt.hist, 'BARTHAG', bins=bins, ec="k")

g.axes[-1].legend()
plt.show()

# %%
bins = np.linspace(df1.ADJOE.min(), df1.ADJOE.max(), 10)
g = sns.FacetGrid(df1, col="windex", hue="POSTSEASON", palette="Set1", col_wrap=2)
g.map(plt.hist, 'ADJOE', bins=bins, ec="k")

g.axes[-1].legend()
plt.show()

# %% [markdown]
# # Pre-processing:  Feature selection/extraction

# %% [markdown]
# ### Lets look at how Adjusted Defense Efficiency plots

# %%
bins = np.linspace(df1.ADJDE.min(), df1.ADJDE.max(), 10)
g = sns.FacetGrid(df1, col="windex", hue="POSTSEASON", palette="Set1", col_wrap=2)
g.map(plt.hist, 'ADJDE', bins=bins, ec="k")
g.axes[-1].legend()
plt.show()

# %% [markdown]
# We see that this data point doesn't impact the ability of a team to get into the Final Four.

# %% [markdown]
# ## Convert Categorical features to numerical values

# %% [markdown]
# Lets look at the postseason:

# %%
df1.groupby(['windex'])['POSTSEASON'].value_counts(normalize=True)
# Out:
# windex  POSTSEASON
# False   S16           0.605263
#         E8            0.263158
#         F4            0.131579
# True    S16           0.500000
#         E8            0.333333
#         F4            0.166667
# Name: POSTSEASON, dtype: float64

# %% [markdown]
# 13% of teams with 6 or less wins above bubble make it into the final four while 17% of teams with 7 or more do.

# %% [markdown]
# Lets convert wins above bubble (winindex) under 7 to 0 and over 7 to 1:

# %%
df1['windex'].replace(to_replace=['False','True'], value=[0,1],inplace=True)
df1.head()
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/generic.py:6586: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
#          TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  ...  \
# 2  Notre Dame  ACC  36  24  118.3  103.3   0.8269   54.0   49.5  15.3  ...
# 3    Virginia  ACC  37  29  119.9   91.0   0.9600   54.8   48.4  15.1  ...
# 4      Kansas  B12  37  32  120.9   90.4   0.9662   55.7   45.1  17.8  ...
# 5      Oregon  P12  37  30  118.4   96.2   0.9163   52.3   48.9  16.1  ...
# 6    Syracuse  ACC  37  23  111.9   93.6   0.8857   50.0   47.3  18.1  ...
#
#    2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR  windex
# 2  52.9  46.5  37.4  36.9   65.5   2.3          E8   6.0  2016       0
# 3  52.6  46.3  40.3  34.7   61.9   8.6          E8   1.0  2016       1
# 4  52.7  43.4  41.3  32.5   70.1  11.6          E8   1.0  2016       1
# 5  52.6  46.1  34.4  36.2   69.0   6.7          E8   1.0  2016       0
# 6  47.2  48.1  36.0  30.7   65.5  -0.3          F4  10.0  2016       0
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Feature selection

# %% [markdown]
# Lets defind feature sets, X:

# %%
X = df1[['G', 'W', 'ADJOE', 'ADJDE', 'BARTHAG', 'EFG_O', 'EFG_D',
       'TOR', 'TORD', 'ORB', 'DRB', 'FTR', 'FTRD', '2P_O', '2P_D', '3P_O',
       '3P_D', 'ADJ_T', 'WAB', 'SEED', 'windex']]
X[0:5]
# Out:
#     G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  TORD   ORB  ...   FTR  \
# 2  36  24  118.3  103.3   0.8269   54.0   49.5  15.3  14.8  32.7  ...  32.9
# 3  37  29  119.9   91.0   0.9600   54.8   48.4  15.1  18.8  29.9  ...  32.1
# 4  37  32  120.9   90.4   0.9662   55.7   45.1  17.8  18.5  32.2  ...  38.6
# 5  37  30  118.4   96.2   0.9163   52.3   48.9  16.1  20.2  34.1  ...  40.3
# 6  37  23  111.9   93.6   0.8857   50.0   47.3  18.1  20.4  33.5  ...  35.4
#
#    FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  SEED  windex
# 2  26.0  52.9  46.5  37.4  36.9   65.5   2.3   6.0       0
# 3  33.4  52.6  46.3  40.3  34.7   61.9   8.6   1.0       1
# 4  37.3  52.7  43.4  41.3  32.5   70.1  11.6   1.0       1
# 5  32.0  52.6  46.1  34.4  36.2   69.0   6.7   1.0       0
# 6  28.0  47.2  48.1  36.0  30.7   65.5  -0.3  10.0       0
#
# [5 rows x 21 columns]

# %% [markdown]
# What are our lables? Round where the given team was eliminated or where their season ended (R68 = First Four, R64 = Round of 64, R32 = Round of 32, S16 = Sweet Sixteen, E8 = Elite Eight, F4 = Final Four, 2ND = Runner-up, Champion = Winner of the NCAA March Madness Tournament for that given year)|

# %%
y = df1['POSTSEASON'].values
y[0:5]
# Out:
# array(['E8', 'E8', 'E8', 'E8', 'F4'], dtype=object)

# %% [markdown]
# ## Normalize Data

# %% [markdown]
# Data Standardization give data zero mean and unit variance (technically should be done after train test split )

# %%
X = preprocessing.StandardScaler().fit(X).transform(X)
X[0:5]
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:1: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   if __name__ == '__main__':
# array([[-0.43331874, -1.26140173,  0.28034482,  2.74329908, -2.45717765,
#          0.10027963,  0.94171924, -1.16188145, -1.71391372,  0.12750511,
#          1.33368704, -0.4942211 , -0.87998988,  0.02784185,  0.00307239,
#          0.22576157,  1.59744386, -1.12106011, -1.0448016 ,  0.49716104,
#         -0.6882472 ],
#        [ 0.40343468,  0.35874728,  0.64758014, -0.90102957,  1.127076  ,
#          0.39390887,  0.38123706, -1.29466791, -0.03522254, -0.62979797,
#         -1.31585883, -0.68542235,  0.55458056, -0.07167795, -0.0829545 ,
#          1.32677295,  0.65081046, -2.369021  ,  0.98050611, -1.14054592,
#          1.45296631],
#        [ 0.40343468,  1.33083669,  0.87710222, -1.0788017 ,  1.29403598,
#          0.72424177, -1.30020946,  0.49794919, -0.16112438, -0.00772758,
#         -0.27908001,  0.86808783,  1.31063795, -0.03850468, -1.33034432,
#          1.70643205, -0.29582294,  0.47355659,  1.94493836, -1.14054592,
#          1.45296631],
#        [ 0.40343468,  0.68277708,  0.30329703,  0.63966222, -0.04972253,
#         -0.52368251,  0.63600169, -0.63073565,  0.55231938,  0.50615665,
#          0.71929959,  1.2743905 ,  0.28317534, -0.07167795, -0.16898138,
#         -0.91321572,  1.29624232,  0.0922352 ,  0.36969903, -1.14054592,
#         -0.6882472 ],
#        [ 0.40343468, -1.58543153, -1.18859646, -0.13068368, -0.87375079,
#         -1.36786658, -0.17924511,  0.69712887,  0.63625394,  0.34387742,
#          2.56246194,  0.10328282, -0.49226814, -1.8630343 ,  0.69128747,
#         -0.30576117, -1.07034117, -1.12106011, -1.88064288,  1.80732661,
#         -0.6882472 ]])

# %% [markdown]
# ## Training and Validation

# %% [markdown]
# Split the data into Training and Validation data.

# %%
# We split the X into train and test to find the best k
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Validation set:', X_val.shape,  y_val.shape)
# Out:
# Train set: (44, 21) (44,)
# Validation set: (12, 21) (12,)

# %% [markdown]
# # Classification

# %% [markdown]
# Now, it is your turn, use the training set to build an accurate model. Then use the validation set  to report the accuracy of the model
# You should use the following algorithm:
# - K Nearest Neighbor(KNN)
# - Decision Tree
# - Support Vector Machine
# - Logistic Regression

# %% [markdown]
# # K Nearest Neighbor(KNN)
#
# <b>Question  1 </b> Build a KNN model using a value of k equals five, find the accuracy on the validation data (X_val and y_val)

# %%
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier

# Set k to 5
k = 5
neighbors = KNeighborsClassifier(n_neighbors = k).fit(X_train, y_train)
yhat = neighbors.predict(X_val)
print("Train set Accuracy: ", accuracy_score(y_train, neighbors.predict(X_train)))
print("Test set Accuracy: ", accuracy_score(y_val, yhat))
# Out:
# Train set Accuracy:  0.6363636363636364
# Test set Accuracy:  0.6666666666666666

# %% [markdown]
# <b>Question 2</b> Determine and print the accuracy for the first 15 values of k the on the validation data:

# %%
Ks = 15
mean_acc = np.zeros((Ks-1))
std_acc = np.zeros((Ks-1))

for n in range(1, Ks):    
    #Train Model and Predict  
    neigh = KNeighborsClassifier(n_neighbors = n).fit(X_train, y_train)
    yhat = neigh.predict(X_val)
    mean_acc[n-1] = accuracy_score(y_val, yhat)
    std_acc[n-1] = np.std(yhat==y_val)/np.sqrt(yhat.shape[0])

print(mean_acc)
# Out:
# [0.33333333 0.33333333 0.5        0.58333333 0.66666667 0.58333333
#  0.58333333 0.66666667 0.58333333 0.58333333 0.58333333 0.5
#  0.58333333 0.58333333]

# %% [markdown]
# Plot model accuracy

# %%
# Plot accuracy
plt.plot(range(1, Ks), mean_acc,'g')
plt.fill_between(range(1, Ks), mean_acc-1*std_acc, mean_acc + 1 * std_acc, alpha=0.10)
plt.legend(('Accuracy ', '+/- 3xstd'))
plt.ylabel('Accuracy ')
plt.xlabel('Number of Neighbors (K)')
plt.tight_layout()
plt.show()

print("Best Accuracy: {}".format(mean_acc.max()))
# Out:
# Best Accuracy: 0.6666666666666666

# %% [markdown]
# # Decision Tree

# %% [markdown]
# The following lines of code fit a <code>DecisionTreeClassifier</code>:

# %%
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

# %% [markdown]
# <b>Question  3</b> Determine the better value for the parameter <code>max_depth</code>

# %%
accuracy = []

offset = 1     # Minimum value
for i in range(offset, 11):
    decision_tree = DecisionTreeClassifier(criterion="entropy", max_depth=i)
    decision_tree.fit(X_train, y_train)

    predTree = decision_tree.predict(X_val)
    accuracy.append(accuracy_score(y_val, predTree))
    
print("The most acurate max_depth is {} with an accuracy of {}".format(accuracy.index(max(accuracy))+offset, max(accuracy)))

decision_tree = DecisionTreeClassifier(criterion="entropy", max_depth=accuracy.index(max(accuracy))+offset)
decision_tree.fit(X_train, y_train)
# Out:
# The most acurate max_depth is 1 with an accuracy of 0.6666666666666666
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %% [markdown]
# # Support Vector Machine

# %% [markdown]
# <b>Question 4</b> Train the support vector machine model and determine the accuracy on the validation data for each kernel. Find the kernel (linear, poly, rbf, sigmoid) that provides the best score on the validation data and train a SVM using it.

# %%
# SVM
from sklearn import svm, metrics

available_kernels = ['linear', 'rbf', 'sigmoid', 'poly']      # rearranged kernel orders to keep the one with better accuracy
for kernel in available_kernels:
    clf = svm.SVC(kernel=kernel)
    clf.fit(X_train, y_train) 

    yhat = clf.predict(X_val)

    f1_score = metrics.f1_score(y_val, yhat, average='weighted') 
    jaccard = metrics.jaccard_similarity_score(y_val, yhat)

    print('Kernel: {}\n\tF1 Score: {}\n\tJaccard: {}\n'.format(kernel, f1_score, jaccard))
# Out:
# Kernel: linear
# 	F1 Score: 0.24216524216524218
# 	Jaccard: 0.25
#
# Kernel: rbf
# 	F1 Score: 0.49122807017543857
# 	Jaccard: 0.5833333333333334
#
# Kernel: sigmoid
# 	F1 Score: 0.44444444444444436
# 	Jaccard: 0.5
#
# Kernel: poly
# 	F1 Score: 0.5333333333333333
# 	Jaccard: 0.6666666666666666
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# <b>Question 5</b> Train a logistic regression model and determine the accuracy of the validation data (set C=0.01)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

log_regression = LogisticRegression(C=0.01, solver='liblinear')
log_regression.fit(X_train, y_train)

yhat = log_regression.predict(X_val)
yhat_prob = log_regression.predict_proba(X_val)

print(classification_report(y_val, yhat))
f1_score = metrics.f1_score(y_val, yhat, average='micro')
print('F1 Score: {}'.format(f1_score))
# Out:
#               precision    recall  f1-score   support
#
#           E8       0.20      0.50      0.29         2
#           F4       1.00      1.00      1.00         2
#          S16       0.80      0.50      0.62         8
#
#    micro avg       0.58      0.58      0.58        12
#    macro avg       0.67      0.67      0.63        12
# weighted avg       0.73      0.58      0.62        12
#
# F1 Score: 0.5833333333333334
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %% [markdown]
# # Model Evaluation using Test set

# %%
from sklearn.metrics import f1_score
# for f1_score please set the average parameter to 'micro'
from sklearn.metrics import log_loss

# %%
def jaccard_index(predictions, true):
    if (len(predictions) == len(true)):
        intersect = 0;
        for x,y in zip(predictions, true):
            if (x == y):
                intersect += 1
        return intersect / (len(predictions) + len(true) - intersect)
    else:
        return -1

# %% [markdown]
# <b>Question  5</b> Calculate the  F1 score and Jaccard Similarity score for each model from above. Use the Hyperparameter that performed best on the validation data. **For f1_score please set the average parameter to 'micro'.**

# %% [markdown]
# ### Load Test set for evaluation

# %%
test_df = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0120ENv3/Dataset/ML0101EN_EDX_skill_up/basketball_train.csv',error_bad_lines=False)
test_df.head()
# Out:
#              TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0  North Carolina  ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1       Villanova   BE  40  35  123.1   90.9   0.9703   56.1   46.7  16.3
# 2      Notre Dame  ACC  36  24  118.3  103.3   0.8269   54.0   49.5  15.3
# 3        Virginia  ACC  37  29  119.9   91.0   0.9600   54.8   48.4  15.1
# 4          Kansas  B12  37  32  120.9   90.4   0.9662   55.7   45.1  17.8
#
#    ...  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR
# 0  ...  30.4  53.9  44.6  32.7  36.2   71.7   8.6         2ND   1.0  2016
# 1  ...  30.0  57.4  44.1  36.2  33.9   66.7   8.9   Champions   2.0  2016
# 2  ...  26.0  52.9  46.5  37.4  36.9   65.5   2.3          E8   6.0  2016
# 3  ...  33.4  52.6  46.3  40.3  34.7   61.9   8.6          E8   1.0  2016
# 4  ...  37.3  52.7  43.4  41.3  32.5   70.1  11.6          E8   1.0  2016
#
# [5 rows x 24 columns]

# %%
test_df['windex'] = np.where(test_df.WAB > 7, 'True', 'False')
test_df1 = test_df[test_df['POSTSEASON'].str.contains('F4|S16|E8', na=False)]
test_Feature = test_df1[['G', 'W', 'ADJOE', 'ADJDE', 'BARTHAG', 'EFG_O', 'EFG_D',
       'TOR', 'TORD', 'ORB', 'DRB', 'FTR', 'FTRD', '2P_O', '2P_D', '3P_O',
       '3P_D', 'ADJ_T', 'WAB', 'SEED', 'windex']]
test_Feature['windex'].replace(to_replace=['False','True'], value=[0,1],inplace=True)
test_X=test_Feature
test_X= preprocessing.StandardScaler().fit(test_X).transform(test_X)
test_X[0:5]
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/generic.py:6586: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:8: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
# array([[-4.08074446e-01, -1.10135297e+00,  3.37365934e-01,
#          2.66479976e+00, -2.46831661e+00,  2.13703245e-01,
#          9.44090550e-01, -1.19216365e+00, -1.64348924e+00,
#          1.45405982e-02,  1.29523097e+00, -6.23533182e-01,
#         -9.31788560e-01,  1.42784371e-01,  1.68876201e-01,
#          2.84500844e-01,  1.62625961e+00, -8.36649260e-01,
#         -9.98500539e-01,  4.84319174e-01, -6.77003200e-01],
#        [ 3.63958290e-01,  3.26326807e-01,  7.03145068e-01,
#         -7.13778644e-01,  1.07370841e+00,  4.82633172e-01,
#          4.77498943e-01, -1.32975879e+00, -6.86193316e-02,
#         -7.35448152e-01, -1.35447914e+00, -8.06829025e-01,
#          3.41737757e-01,  4.96641291e-02,  9.40576311e-02,
#          1.37214061e+00,  6.93854620e-01, -2.00860931e+00,
#          9.80549967e-01, -1.19401460e+00,  1.47709789e+00],
#        [ 3.63958290e-01,  1.18293467e+00,  9.31757027e-01,
#         -8.78587347e-01,  1.23870131e+00,  7.85179340e-01,
#         -9.22275877e-01,  5.27775662e-01, -1.86734575e-01,
#         -1.19385964e-01, -3.17636057e-01,  6.82449703e-01,
#          1.01292055e+00,  8.07042098e-02, -9.90811637e-01,
#          1.74718880e+00, -2.38550367e-01,  6.60855252e-01,
#          1.92295497e+00, -1.19401460e+00,  1.47709789e+00],
#        [ 3.63958290e-01,  6.11862762e-01,  3.60227129e-01,
#          7.14563447e-01, -8.92254236e-02, -3.57772849e-01,
#          6.89586037e-01, -6.41783067e-01,  4.82585136e-01,
#          3.89534973e-01,  6.80805434e-01,  1.07195337e+00,
#          1.00800346e-01,  4.96641291e-02,  1.92390609e-02,
#         -8.40643737e-01,  1.32958529e+00,  3.02756347e-01,
#          3.83693465e-01, -1.19401460e+00, -6.77003200e-01],
#        [ 3.63958290e-01, -1.38688893e+00, -1.12575060e+00,
#          3.92401673e-04, -9.03545224e-01, -1.13094639e+00,
#          1.09073363e-02,  7.34168378e-01,  5.61328631e-01,
#          2.28823098e-01,  2.52408203e+00, -5.07336709e-02,
#         -5.87592258e-01, -1.62650023e+00,  7.67424763e-01,
#         -2.40566627e-01, -1.00142717e+00, -8.36649260e-01,
#         -1.81525154e+00,  1.82698619e+00, -6.77003200e-01]])

# %%
test_y = test_df1['POSTSEASON'].values
test_y[0:5]
# Out:
# array(['E8', 'E8', 'E8', 'E8', 'F4'], dtype=object)

# %% [markdown]
# KNN

# %%
KNN_pred = neighbors.predict(test_X)

KNN_accuracy = metrics.accuracy_score(test_y, KNN_pred)
KNN_f1_score = metrics.f1_score(test_y, KNN_pred, average='micro') 
KNN_jaccard = jaccard_index(test_y, KNN_pred)

print('KNN:\n\tAccuracy Score: {}\n\tF1 Score: {}\n\tJaccard: {}\n'.format(KNN_accuracy, KNN_f1_score, KNN_jaccard))
# Out:
# KNN:
# 	Accuracy Score: 0.6285714285714286
# 	F1 Score: 0.6285714285714286
# 	Jaccard: 0.4583333333333333

# %% [markdown]
# Decision Tree

# %%
DT_pred = decision_tree.predict(test_X)

DT_accuracy = metrics.accuracy_score(test_y, DT_pred)
DT_f1_score = metrics.f1_score(test_y, DT_pred, average='micro') 
DT_jaccard = jaccard_index(test_y, DT_pred)

print('DT:\n\tAccuracy Score: {}\n\tF1 Score: {}\n\tJaccard: {}\n'.format(DT_accuracy, DT_f1_score, DT_jaccard))
# Out:
# DT:
# 	Accuracy Score: 0.6428571428571429
# 	F1 Score: 0.6428571428571429
# 	Jaccard: 0.47368421052631576

# %% [markdown]
# SVM

# %%
SVM_pred = clf.predict(test_X)

SVM_accuracy = metrics.accuracy_score(test_y, SVM_pred)
SVM_f1_score = metrics.f1_score(test_y, SVM_pred, average='micro') 
SVM_jaccard = jaccard_index(test_y, SVM_pred)

print('SVM:\n\tAccuracy Score: {}\n\tF1 Score: {}\n\tJaccard: {}\n'.format(SVM_accuracy, SVM_f1_score, SVM_jaccard))
# Out:
# SVM:
# 	Accuracy Score: 0.6857142857142857
# 	F1 Score: 0.6857142857142857
# 	Jaccard: 0.5217391304347826

# %% [markdown]
# Logistic Regression

# %%
LR_pred = log_regression.predict(test_X)

LR_accuracy = metrics.accuracy_score(test_y, LR_pred)
LR_f1_score = metrics.f1_score(test_y, LR_pred, average='micro') 
LR_jaccard = jaccard_index(test_y, LR_pred)

print('LR:\n\tAccuracy Score: {}\n\tF1 Score: {}\n\tJaccard: {}\n'.format(LR_accuracy, LR_f1_score, LR_jaccard))
# Out:
# LR:
# 	Accuracy Score: 0.6857142857142857
# 	F1 Score: 0.6857142857142857
# 	Jaccard: 0.5217391304347826

# %% [markdown]
# # Report
# You should be able to report the accuracy of the built model using different evaluation metrics:

# %% [markdown]
# | Algorithm          | Accuracy | Jaccard  | F1-score  | LogLoss |
# |--------------------|----------|----------|-----------|---------|
# | KNN                |0.628571  | 0.458333 | 0.628571  | NA      |
# | Decision Tree      |0.642857  | 0.473684 | 0.642857  | NA      |
# | SVM                |0.685714  | 0.521739 | 0.685714  | NA      |
# | LogisticRegression |0.685714  | 0.521739 | 0.685714  | 1.03719 |

# %% [markdown]
# Something to keep in mind when creating models to predict the results of basketball tournaments or sports in general is that is quite hard due to so many factors influencing the game. Even in sports betting an accuracy of 55% and over is considered good as it indicates profits.

# %% [markdown]
# # My Report

# %%
print('| Algorithm          | Accuracy           | Jaccard            | F1-score')
print('|','-'*18, '|', '-'*18, '|', '-'*18, '|', '-'*18)
print('| KNN                | {} | {} | {}'.format(KNN_accuracy, KNN_jaccard, KNN_f1_score))
print('| Decision Tree      | {} | {} | {}'.format(DT_accuracy, DT_jaccard, DT_f1_score))
print('| SVM                | {} | {} | {}'.format(SVM_accuracy, SVM_jaccard, SVM_f1_score))
print('| LogisticRegression | {} | {} | {}'.format(LR_accuracy, LR_jaccard, LR_f1_score))
# Out:
# | Algorithm          | Accuracy           | Jaccard            | F1-score
# | ------------------ | ------------------ | ------------------ | ------------------
# | KNN                | 0.6285714285714286 | 0.4583333333333333 | 0.6285714285714286
# | Decision Tree      | 0.6428571428571429 | 0.47368421052631576 | 0.6428571428571429
# | SVM                | 0.6857142857142857 | 0.5217391304347826 | 0.6857142857142857
# | LogisticRegression | 0.6857142857142857 | 0.5217391304347826 | 0.6857142857142857

# %% [markdown]
# <h2>Want to learn more?</h2>
#
# Also, you can use Watson Studio to run these notebooks faster with bigger datasets. Watson Studio is IBM's leading cloud solution for data scientists, built by data scientists. With Jupyter notebooks, RStudio, Apache Spark and popular libraries pre-packaged in the cloud, Watson Studio enables data scientists to collaborate on their projects without having to install anything. Join the fast-growing community of Watson Studio users today with a free account at <a href="https://cocl.us/ML0101EN_DSX">Watson Studio</a>
#
# <h4>Authors: <a href="https://www.linkedin.com/in/azim-hirjani-691a07179/">Azim Hirjani</a> and <a href="https://www.linkedin.com/in/joseph-s-50398b136/">Joseph Santarcangelo</a></h4>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.
#
#
#
# <hr>
#
# <p>Copyright &copy; 2018 <a href="https://cocl.us/DX0108EN_CC">Cognitive Class</a>. This notebook and its source code are released under the terms of the <a href="https://bigdatauniversity.com/mit-license/">MIT License</a>.</p>
